# %%
pip install yfinance pandas matplotlib seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
tickers = "AAPL"

# %%
data = yf.download(tickers)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099584
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094388
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087461
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089625
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092224
# ...                ...         ...         ...         ...         ...
# 2023-05-26  173.320007  175.770004  173.110001  175.429993  175.429993
# 2023-05-30  176.960007  178.990005  176.570007  177.300003  177.300003
# 2023-05-31  177.330002  179.350006  176.759995  177.250000  177.250000
# 2023-06-01  177.699997  180.119995  176.929993  180.089996  180.089996
# 2023-06-02  181.029999  181.779999  179.259995  180.949997  180.949997
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
start="2018-04-04"

# %%
end="2023-04-05"

# %%
data=yf.download(tickers,start=start,end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-04-04   41.220001   43.002499   41.192501   42.902500   40.843361
# 2018-04-05   43.145000   43.557499   43.020000   43.200001   41.126591
# 2018-04-06   42.742500   43.119999   42.049999   42.095001   40.074615
# 2018-04-09   42.470001   43.272499   42.462502   42.512501   40.472080
# 2018-04-10   43.250000   43.500000   42.882500   43.312500   41.233681
# ...                ...         ...         ...         ...         ...
# 2023-03-29  159.369995  161.050003  159.350006  160.770004  160.547943
# 2023-03-30  161.529999  162.470001  161.270004  162.360001  162.135742
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.672226
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  165.940475
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.401230
#
#                Volume
# Date
# 2018-04-04  138422000
# 2018-04-05  107732800
# 2018-04-06  140021200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1260 entries, 2018-04-04 to 2023-04-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1260 non-null   float64
#  1   High       1260 non-null   float64
#  2   Low        1260 non-null   float64
#  3   Close      1260 non-null   float64
#  4   Adj Close  1260 non-null   float64
#  5   Volume     1260 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.9 KB

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()

# %%
data = yf.download(tickers, period="1d")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="5d")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="1mo")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="3mo")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="6mo")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="1y")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="2y")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="5y")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="10y")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="10y")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="ytd")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="max")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="1d",interval="1m")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="5d",interval="2m")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="1mo",interval="15m")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="6mo",interval="60m")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="2y",interval="1h")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="5y",interval="1d")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="10y",interval="5d")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="ytd",interval="1wk")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="ytd",interval="1mo")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download(tickers, period="max",interval="3mo")

plt.figure(figsize=(14, 6), dpi=80)
plt.plot(data.Close)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
